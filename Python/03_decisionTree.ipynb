# %% [markdown]
# <a href="https://colab.research.google.com/github/MasahiroAraki/MLCourse/blob/master/Python/03_decisionTree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 3. 識別 ー概念学習ー

# %% [markdown]
# irisデータで決定木を作成します。

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import cross_val_score

# %%
iris = load_iris()
X = iris.data
y = iris.target

# %% [markdown]
# まず、全学習データで決定木を作成し、表示します。

# %%
clf = DecisionTreeClassifier()
clf.fit(X, y)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# 木の表示は、教科書p.57のコードよりもかなり簡単になっています。
# ただし、Google colabでは解像度の調整がうまくゆかないようなので、下記リンクにあるgraphvizを使ったコードのほうがよいかもしれません。
# https://scikit-learn.org/stable/modules/tree.html#classification

# %%
plot_tree(clf, filled=True, feature_names=iris.feature_names, class_names=iris.target_names)
plt.show()

# %% [markdown]
# 次に、交差確認法で性能評価を行います。

# %%
scores = cross_val_score(clf, X, y, cv=10)
print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std()*2))
# Out:
# Accuracy: 0.95 (+/- 0.09)

# %% [markdown]
# 課題: scikit-learn付属のwineデータで決定木の作成、表示を行ってください。その際、木の深さと性能の関係も調べてください。

# %% [markdown]
# ## 参考
#
# * Decision trees https://scikit-learn.org/stable/modules/tree.html
