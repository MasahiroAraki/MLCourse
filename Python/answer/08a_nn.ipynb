# %% [markdown]
# <a href="https://colab.research.google.com/github/MasahiroAraki/MLCourse/blob/master/Python/answer/08a_nn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 第8章 ニューラルネットワーク
#
# ## 課題
#
# 活性化関数sigmoid、最適化器sgd（最急勾配法）で多階層ネットワークを構成し、勾配消失のために学習が進まないことを確認してください。次に、活性化関数を変更して、学習がうまくできることを確認してください。余力があれば、最適化器入れ替えの効果についても確認してください。

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %% [markdown]
# ## データの読み込み

# %%
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.mnist.load_data()

# %% [markdown]
# 入力値のとりうる範囲を0-255から0-1に変換します。

# %%
X_train = X_train / 255.0
X_test = X_test / 255.0

# %% [markdown]
# 正解をone-hotベクトルに変換します。

# %%
y_train = tf.keras.utils.to_categorical(y_train)
y_test = tf.keras.utils.to_categorical(y_test)

# %% [markdown]
# ## ニューラルネットワークの構造と学習時のハイパーパラメータの設定
#
# 3層のフィードフォワード方で学習します。

# %%
af = 'sigmoid'
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation=af),
    tf.keras.layers.Dense(128, activation=af),
    tf.keras.layers.Dense(128, activation=af),
    tf.keras.layers.Dense(128, activation=af),
    tf.keras.layers.Dense(10,  activation='softmax')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               100480
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 151,306
# Trainable params: 151,306
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# 損失関数と最適化器を指定します。metricsは学習時に表示される数値で、学習が進んでいることを確認できるように設定します。

# %%
model.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['acc'])

# %% [markdown]
# ミニバッチのサイズと、繰り返し数を指定して学習を行います。

# %%
model.fit(X_train, y_train, batch_size=200, epochs=5)
# Out:
# Epoch 1/5
# 300/300 [==============================] - 1s 2ms/step - loss: 2.3284 - acc: 0.1052
# Epoch 2/5
# 300/300 [==============================] - 1s 2ms/step - loss: 2.3019 - acc: 0.1108
# Epoch 3/5
# 300/300 [==============================] - 1s 2ms/step - loss: 2.3013 - acc: 0.1140
# Epoch 4/5
# 300/300 [==============================] - 1s 2ms/step - loss: 2.3012 - acc: 0.1136
# Epoch 5/5
# 300/300 [==============================] - 1s 2ms/step - loss: 2.3013 - acc: 0.1130

# %% [markdown]
# 評価用データで評価します。

# %%
score = model.evaluate(X_test, y_test)
print(f"Accuracy: {score[1]:.2}")
# Out:
# 313/313 [==============================] - 0s 804us/step - loss: 2.3006 - acc: 0.1135
# Accuracy: 0.11

# %% [markdown]
# 10クラス問題で正解率が10%程度なので、まったく学習ができていないことがわかります。

# %% [markdown]
# 活性化関数を変更します。

# %%
af = 'relu'

model2 = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation=af),
    tf.keras.layers.Dense(128, activation=af),
    tf.keras.layers.Dense(128, activation=af),
    tf.keras.layers.Dense(128, activation=af),
    tf.keras.layers.Dense(10,  activation='softmax')
])

# %%
model2.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['acc'])

# %%
model2.fit(X_train, y_train, batch_size=200, epochs=5)
# Out:
# Epoch 1/5
# 300/300 [==============================] - 1s 2ms/step - loss: 2.1780 - acc: 0.2481
# Epoch 2/5
# 300/300 [==============================] - 1s 2ms/step - loss: 0.9969 - acc: 0.7664
# Epoch 3/5
# 300/300 [==============================] - 1s 2ms/step - loss: 0.5024 - acc: 0.8587
# Epoch 4/5
# 300/300 [==============================] - 1s 2ms/step - loss: 0.4002 - acc: 0.8838
# Epoch 5/5
# 300/300 [==============================] - 1s 3ms/step - loss: 0.3460 - acc: 0.9002

# %%
score = model2.evaluate(X_test, y_test)
print(f"Accuracy: {score[1]:.2}")
# Out:
# 313/313 [==============================] - 1s 1ms/step - loss: 0.3099 - acc: 0.9090
# Accuracy: 0.91

# %% [markdown]
# もとのネットワークで、最適化器のみ変更してみます。

# %%
af = 'sigmoid'
model3 = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation=af),
    tf.keras.layers.Dense(128, activation=af),
    tf.keras.layers.Dense(128, activation=af),
    tf.keras.layers.Dense(128, activation=af),
    tf.keras.layers.Dense(10,  activation='softmax')
])

# %%
model3.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['acc'])

# %%
model3.fit(X_train, y_train, batch_size=200, epochs=5)
# Out:
# Epoch 1/5
# 300/300 [==============================] - 1s 2ms/step - loss: 1.7698 - acc: 0.3953
# Epoch 2/5
# 300/300 [==============================] - 1s 2ms/step - loss: 0.4061 - acc: 0.8933
# Epoch 3/5
# 300/300 [==============================] - 1s 2ms/step - loss: 0.2463 - acc: 0.9319
# Epoch 4/5
# 300/300 [==============================] - 1s 2ms/step - loss: 0.1824 - acc: 0.9492
# Epoch 5/5
# 300/300 [==============================] - 1s 2ms/step - loss: 0.1385 - acc: 0.9618

# %%
score = model3.evaluate(X_test, y_test)
print(f"Accuracy: {score[1]:.2}")
# Out:
# 313/313 [==============================] - 0s 917us/step - loss: 0.1503 - acc: 0.9570
# Accuracy: 0.96

# %% [markdown]
# 活性化関数と最適化器の両方を変えてみます。

# %%
af = 'relu'

model4 = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation=af),
    tf.keras.layers.Dense(128, activation=af),
    tf.keras.layers.Dense(128, activation=af),
    tf.keras.layers.Dense(128, activation=af),
    tf.keras.layers.Dense(10,  activation='softmax')
])

# %%
model4.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['acc'])

# %%
model4.fit(X_train, y_train, batch_size=200, epochs=5)
# Out:
# Epoch 1/5
# 300/300 [==============================] - 1s 2ms/step - loss: 0.6747 - acc: 0.8040
# Epoch 2/5
# 300/300 [==============================] - 1s 2ms/step - loss: 0.1321 - acc: 0.9604
# Epoch 3/5
# 300/300 [==============================] - 1s 2ms/step - loss: 0.0911 - acc: 0.9722
# Epoch 4/5
# 300/300 [==============================] - 1s 2ms/step - loss: 0.0651 - acc: 0.9797
# Epoch 5/5
# 300/300 [==============================] - 1s 2ms/step - loss: 0.0495 - acc: 0.9844

# %%
score = model4.evaluate(X_test, y_test)
print(f"Accuracy: {score[1]:.2}")
# Out:
# 313/313 [==============================] - 0s 837us/step - loss: 0.0807 - acc: 0.9755
# Accuracy: 0.98

# %% [markdown]
# 適切に設定を行うと、学習効率が上がることがわかります。
