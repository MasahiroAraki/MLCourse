# %% [markdown]
# # 第1週の補足

# %% [markdown]
# # pandasのDataFrameとscikit-learnの接続について
#
#
# scikit-learnのメソッドで、パターン行列Xを引数とするものはほとんどarray-likeオブジェクトを型として指定しています。これは、行列に見える形式のものであれば受け取った方が変換してくれるというものなので、pandasのDataFrameとして処理したデータを明示的にndarrayに変換することなくコーディングすることができます。

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_breast_cancer
from sklearn.manifold import TSNE
from sklearn import preprocessing

# %%
bc = load_breast_cancer(as_frame=True)
X = bc.data
y = bc.target

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
X.describe()
# Out:
#        mean radius  mean texture  mean perimeter    mean area  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        mean smoothness  mean compactness  mean concavity  mean concave points  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# ...

# %%
tsne = TSNE(perplexity=30)
X2 = tsne.fit_transform(X)

# %%
type(X2)
# Out:
# numpy.ndarray

# %% [markdown]
# 質問：plt.plot(X2\[y==0,0\], X2\[y==0,1\],"ro")の引数
#
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html

# %%
plt.plot(X2[y==0,0], X2[y==0,1],"ro")
plt.plot(X2[y==1,0], X2[y==1,1],"bx")

# %%
y==0
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 564     True
# 565     True
# 566     True
# 567     True
# 568    False
# Name: target, Length: 569, dtype: bool

# %% [markdown]
# 質問：分割学習法は何事例程度から実施するのか
#
# 分割学習法を用いるのは、評価用データの分布が未知データの分布を十分に反映できているとみなされることが条件です。

# %% [markdown]
# 関数のプロット

# %%
import numpy as np
import math
import matplotlib.pyplot as plt

# 描画範囲の指定
# x = np.arange(x軸の最小値, x軸の最大値, 刻み)
x = np.arange(-2, 2, 0.1)

# 計算式
y = np.exp(-(x*x))

# 横軸の変数。縦軸の変数。
plt.plot(x, y)

# 描画実行
plt.show()
