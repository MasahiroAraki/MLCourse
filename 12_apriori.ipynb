# %% [markdown]
# <a href="https://colab.research.google.com/github/MasahiroAraki/MLCourse/blob/master/12_apriori.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 第12章 パターンマイニング

# %% [markdown]
# ## 頻出項目集合抽出
#
# Aprioriアルゴリズムの実装
#
# http://rasbt.github.io/mlxtend/api_subpackages/mlxtend.frequent_patterns/

# %%
# colabで実行
# !pip install -U mlxtend
import pkg_resources, imp
imp.reload(pkg_resources)
# Out:
# Requirement already up-to-date: mlxtend in /usr/local/lib/python3.6/dist-packages (0.17.2)
# Requirement already satisfied, skipping upgrade: joblib>=0.13.2 in /usr/local/lib/python3.6/dist-packages (from mlxtend) (0.15.1)
# Requirement already satisfied, skipping upgrade: scikit-learn>=0.20.3 in /usr/local/lib/python3.6/dist-packages (from mlxtend) (0.22.2.post1)
# Requirement already satisfied, skipping upgrade: pandas>=0.24.2 in /usr/local/lib/python3.6/dist-packages (from mlxtend) (1.0.4)
# Requirement already satisfied, skipping upgrade: numpy>=1.16.2 in /usr/local/lib/python3.6/dist-packages (from mlxtend) (1.18.5)
# Requirement already satisfied, skipping upgrade: setuptools in /usr/local/lib/python3.6/dist-packages (from mlxtend) (47.1.1)
# Requirement already satisfied, skipping upgrade: matplotlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from mlxtend) (3.2.1)
# Requirement already satisfied, skipping upgrade: scipy>=1.2.1 in /usr/local/lib/python3.6/dist-packages (from mlxtend) (1.4.1)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.24.2->mlxtend) (2018.9)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.24.2->mlxtend) (2.8.1)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib>=3.0.0->mlxtend) (1.2.0)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /usr/local/lib/python3.6/dist-packages (from matplotlib>=3.0.0->mlxtend) (0.10.0)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib>=3.0.0->mlxtend) (2.4.7)
# Requirement already satisfied, skipping upgrade: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.6.1->pandas>=0.24.2->mlxtend) (1.12.0)
# <module 'pkg_resources' from '/usr/local/lib/python3.6/dist-packages/pkg_resources/__init__.py'>

# %%
import numpy as np
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules, fpgrowth

# %% [markdown]
# 例題12.1 のデータを読み込んで、pandasのDataFrameに変換。項目がアルファベット順にソートされていることに注意。

# %%
dataset = [['Milk', 'Bread', 'Butter'],
  ['Milk', 'Bread', 'Jam'],
  ['Milk', 'Magazine'],
  ['Bread', 'Butter'],
  ['Milk', 'Bread', 'Butter', 'Jam'],
  ['Magazine'],
  ['Milk', 'Bread', 'Jam', 'Magazine'],
  ['Jam']]

# %%
te = TransactionEncoder()
te_ary = te.fit(dataset).transform(dataset)
df = pd.DataFrame(te_ary, columns=te.columns_)
df
# Out:
#    Bread  Butter    Jam  Magazine   Milk
# 0   True    True  False     False   True
# 1   True   False   True     False   True
# 2  False   False  False      True   True
# 3   True    True  False     False  False
# 4   True    True   True     False   True
# 5  False   False  False      True  False
# 6   True   False   True      True   True
# 7  False   False   True     False  False

# %% [markdown]
# Aprioriアルゴリズムで3事例以上出現する項目集合を抽出

# %%
freq = apriori(df, min_support= 3/len(df), use_colnames=True)
freq
# Out:
#    support            itemsets
# 0    0.625             (Bread)
# 1    0.375            (Butter)
# 2    0.500               (Jam)
# 3    0.375          (Magazine)
# 4    0.625              (Milk)
# 5    0.375     (Butter, Bread)
# 6    0.375        (Jam, Bread)
# 7    0.500       (Milk, Bread)
# 8    0.375         (Jam, Milk)
# 9    0.375  (Jam, Bread, Milk)

# %% [markdown]
# ## 規則抽出

# %%
association_rules(freq, metric="confidence", min_threshold=0.7)
# Out:
#      antecedents    consequents  antecedent support  ...  lift  leverage  conviction
# 0       (Butter)        (Bread)               0.375  ...  1.60  0.140625         inf
# 1          (Jam)        (Bread)               0.500  ...  1.20  0.062500       1.500
# 2         (Milk)        (Bread)               0.625  ...  1.28  0.109375       1.875
# 3        (Bread)         (Milk)               0.625  ...  1.28  0.109375       1.875
# 4          (Jam)         (Milk)               0.500  ...  1.20  0.062500       1.500
# 5   (Jam, Bread)         (Milk)               0.375  ...  1.60  0.140625         inf
# 6    (Jam, Milk)        (Bread)               0.375  ...  1.60  0.140625         inf
# 7  (Milk, Bread)          (Jam)               0.500  ...  1.50  0.125000       2.000
# 8          (Jam)  (Milk, Bread)               0.500  ...  1.50  0.125000       2.000
#
# [9 rows x 9 columns]

# %% [markdown]
# supermarket.arffでFPGrowth（Aprioriの高速化版）を試してみます。データをダウンロードし、scipyのloadarffでWekaのarff形式のデータを読み込みます。その際、読み込みエラーを回避するために文字列置換を行い、最終的にpandasのDataFrameで値をTrue/Falseとし、最終列のtotalは除きます。

# %%
# !wget https://raw.githubusercontent.com/fracpete/wekamooc/master/dataminingwithweka/data/supermarket.arff
# Out:
# --2020-06-13 07:14:18--  https://raw.githubusercontent.com/fracpete/wekamooc/master/dataminingwithweka/data/supermarket.arff
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2025871 (1.9M) [text/plain]
# Saving to: ‘supermarket.arff.1’
#
# supermarket.arff.1  100%[===================>]   1.93M  --.-KB/s    in 0.1s
#
# 2020-06-13 07:14:18 (15.9 MB/s) - ‘supermarket.arff.1’ saved [2025871/2025871]

# %%
# !sed -e "s/{ t}/{t}/" supermarket.arff > supermarket2.arff

# %%
from scipy.io import arff
data, meta = arff.loadarff('supermarket2.arff')
df = pd.DataFrame(data)
df2 = df.replace({b'?':False, b't':True})
df2 = df2.drop('total', axis=1)
df2
# Out:
#       department1  department2  ...  department215  department216
# 0           False        False  ...          False          False
# 1            True        False  ...          False          False
# 2           False        False  ...          False          False
# 3            True        False  ...          False          False
# 4           False        False  ...          False          False
# ...           ...          ...  ...            ...            ...
# 4622        False        False  ...          False          False
# 4623        False        False  ...          False          False
# 4624        False        False  ...          False          False
# 4625        False        False  ...          False          False
# 4626         True        False  ...          False          False
#
# [4627 rows x 216 columns]

# %% [markdown]
# FPGrowthで頻出項目集合を求め、association_rulesで規則を抽出します。

# %%
freq2 = fpgrowth(df2, min_support=0.3, use_colnames=True)

# %%
association_rules(freq2, metric="lift", min_threshold=1.2)
# Out:
#                        antecedents  ... conviction
# 0     (vegetables, bread and cake)  ...   1.631011
# 1          (bread and cake, fruit)  ...   1.567679
# 2                     (vegetables)  ...   1.259095
# 3                          (fruit)  ...   1.273204
# 4         (vegetables, milk-cream)  ...   1.605033
# 5              (milk-cream, fruit)  ...   1.571313
# 6                     (vegetables)  ...   1.191945
# 7                          (fruit)  ...   1.197473
# 8            (baking needs, fruit)  ...   1.664513
# 9                     (vegetables)  ...   1.185540
# 10      (vegetables, frozen foods)  ...   1.571293
# 11           (fruit, frozen foods)  ...   1.634323
# 12                    (vegetables)  ...   1.172234
# 13                         (fruit)  ...   1.162956
# 14  (bread and cake, frozen foods)  ...   1.503027
# 15      (bread and cake, biscuits)  ...   1.500612
# 16                  (frozen foods)  ...   1.237656
# 17                      (biscuits)  ...   1.284359
# 18          (vegetables, biscuits)  ...   1.763238
# 19                         (fruit)  ...   1.176358
# 20             (party snack foods)  ...   1.379689
# 21                      (biscuits)  ...   1.276615
#
# [22 rows x 9 columns]

# %% [markdown]
# ## 行列分解
#
# 小規模な映画評価データを使って、行列分解を行います。

# %% [markdown]
# ライブラリの読み込み

# %%
import numpy as np
from sklearn.decomposition import NMF

# %% [markdown]
# <a href="http://www.quuxlabs.com/blog/2010/09/matrix-factorization-a-simple-tutorial-and-implementation-in-python/">参考ページ</a>のデータ例を使用します。縦がユーザ、横が映画、数値が1-5の5段階評価で、0は評価なしです。

# %%
X = np.array([
    [5,3,0,1],
    [4,0,0,1],
    [1,1,0,5],
    [1,0,0,4],
    [0,1,5,4]
])

# %% [markdown]
# ここでは、非負値行列分解NMFを使います。NMFはXを非負の行列WとHに分解します。引数n_componentsは潜在変数の次元数です。

# %%
model = NMF(n_components = 2)
W = model.fit_transform(X)
H = model.components_

# %% [markdown]
# 空所の値を予測してみます。似たようなユーザを参考に、埋められた値の妥当性を評価してみてください。

# %%
np.set_printoptions(suppress=True)
np.dot(W,H)
# Out:
# array([[5.2558264 , 1.99313836, 0.        , 1.45512772],
#        [3.50429478, 1.32891458, 0.        , 0.9701988 ],
#        [1.31294288, 0.94415991, 1.94956896, 3.94609389],
#        [0.98129195, 0.72179987, 1.52759811, 3.0788454 ],
#        [0.        , 0.65008935, 2.84003662, 5.21894555]])

# %% [markdown]
# 人を表す2次元ベクトルを表示します。同じような評価をする人が似たベクトルになっていることを確認してください。

# %%
W
# Out:
# array([[0.        , 2.37453733],
#        [0.        , 1.58321035],
#        [1.35650216, 0.59317634],
#        [1.06289656, 0.44333929],
#        [1.97608595, 0.        ]])

# %% [markdown]
# 映画を表す2次元ベクトルを表示します。同じような評価をされる映画がないので、それぞれ異なったベクトルになっていることを確認してください。

# %%
H.T
# Out:
# array([[0.        , 2.21341073],
#        [0.32897828, 0.83937967],
#        [1.43720298, 0.        ],
#        [2.6410519 , 0.61280474]])

# %% [markdown]
# ## 課題1
#
# 上記の規則抽出のコード例で求めた規則よりも、Lift値の高い規則を探すにはどうすればよいでしょうか。

# %% [markdown]
# ## 課題2
#
# 教科書p.226の演習問題12-3の手順に従い、MovieLensデータセットに対してscikit-surpriseを用いてNMFを行ってください。余力があれば、ハイパーパラメータを変更して、性能に与える影響を観察してください。
