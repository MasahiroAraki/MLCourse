# %% [markdown]
# # 画像処理

# %% [markdown]
# ## OpenCVを用いた画像処理
#
# [OpenCV](http://opencv.org/)(Open Source Computer Vision Library) はBSDライセンスで公開されている画像処理ライブラリです。Pythonのインタフェースが用意されているので、比較的手軽に利用できます。
#
# OpenCVはAnaconda NavigatorのEnvironmentsからインストールできます。

# %% [markdown]
# ### 参考資料
#
# * [機械学習のためのOpenCV入門](https://qiita.com/icoxfog417/items/53e61496ad980c41a08e)
# * [OpenCVとは？ 最新3.0の新機能概要とモジュール構成](https://postd.cc/image-processing-101/)
# * [画像処理入門講座 : OpenCVとPythonで始める画像処理](https://www.buildinsider.net/small/opencv/001)

# %%
import numpy as np
import cv2, matplotlib
import matplotlib.pyplot as plt

print(cv2.__version__)
# Out:
# 3.4.3

# %% [markdown]
# 画像表示

# %%
def read_img(name_i):
    img = cv2.imread(name_i)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # 色の変換
    return img

# 画像の読み込み
img = read_img('a.png')

# 画像の表示
plt.imshow(img)

# %% [markdown]
# 濃淡画像への変換

# %%
gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
plt.imshow(gray)
plt.gray()

# %% [markdown]
# ## フィルタの適用
#
# X方向のSobelフィルタ

# %%
sobelx = cv2.Sobel(gray, cv2.CV_64F, 1, 0, ksize=5)
plt.imshow(sobelx)
plt.gray()

# %% [markdown]
# y方向のSobelフィルタ

# %%
sobely = cv2.Sobel(gray, cv2.CV_64F, 0, 1, ksize=5)
plt.imshow(sobely)
plt.gray()

# %%
canny_img = cv2.Canny(gray, 200, 50)
plt.imshow(canny_img)
plt.gray()

# %% [markdown]
# 画像を2値化して、輪郭を抽出。

# %%
ret, thresh = cv2.threshold(gray, 128, 255, 0)
im2, contours, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
plt.imshow(im2)

# %%
canny_img = cv2.Canny(im2, 150, 10)
plt.imshow(canny_img)

# %%
g2 = cv2.drawContours(img, contours, -1, (0,255,0), 3)
plt.imshow(g2)
