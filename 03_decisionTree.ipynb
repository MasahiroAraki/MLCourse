# %% [markdown]
# <a href="https://colab.research.google.com/github/MasahiroAraki/MLCourse/blob/master/03_decision-tree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 3. 識別 ー概念学習ー

# %% [markdown]
# 例：第2章で用いたirisデータで決定木を作成します。

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import cross_val_score

# %%
iris = load_iris()
X = iris.data
y = iris.target

# %% [markdown]
# まず、全学習データで決定木を作成し、表示します。

# %%
clf = DecisionTreeClassifier()
clf.fit(X, y)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %% [markdown]
# 木の表示は、教科書p.57のコードよりもかなり簡単になっています。

# %%
plot_tree(clf, filled=True, feature_names=iris.feature_names,class_names=iris.target_names,) 
plt.show()

# %% [markdown]
# 次に、交差確認法で性能評価を行います。

# %%
scores = cross_val_score(clf, X, y, cv=10)
print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std()*2))
# Out:
# Accuracy: 0.96 (+/- 0.09)

# %% [markdown]
# 課題: wineデータで決定木の作成、表示を行ってください。また、過学習の状況および過学習への対処をコーディングで確認してください。

# %% [markdown]
# ## 参考
#
# * Decision trees https://scikit-learn.org/stable/modules/tree.html
