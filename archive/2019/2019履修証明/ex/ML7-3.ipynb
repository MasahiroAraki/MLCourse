# %% [markdown]
# ## 実践演習7-3
#
# sklearnのSVMでGridSearchを行います。

# %%
from sklearn.datasets import load_wine
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# Wineデータを読み込み、パターン行列Xと教師ベクトルyにデータを格納します。

# %%
wine = load_wine()
X = wine.data
y = wine.target
print(wine.DESCR)
# Out:
# .. _wine_dataset:
#
# Wine recognition dataset
# ------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 178 (50 in each of three classes)
#     :Number of Attributes: 13 numeric, predictive attributes and the class
#     :Attribute Information:
#  		- Alcohol
#  		- Malic acid
#  		- Ash
# 		- Alcalinity of ash
#  		- Magnesium
# 		- Total phenols
#  		- Flavanoids
#  		- Nonflavanoid phenols
#  		- Proanthocyanins
# 		- Color intensity
#  		- Hue
#  		- OD280/OD315 of diluted wines
#  		- Proline
#
#     - class:
#             - class_0
#             - class_1
#             - class_2
#
#     :Summary Statistics:
#
#     ============================= ==== ===== ======= =====
#                                    Min   Max   Mean     SD
#     ============================= ==== ===== ======= =====
#     Alcohol:                      11.0  14.8    13.0   0.8
#     Malic Acid:                   0.74  5.80    2.34  1.12
#     Ash:                          1.36  3.23    2.36  0.27
#     Alcalinity of Ash:            10.6  30.0    19.5   3.3
#     Magnesium:                    70.0 162.0    99.7  14.3
#     Total Phenols:                0.98  3.88    2.29  0.63
#     Flavanoids:                   0.34  5.08    2.03  1.00
#     Nonflavanoid Phenols:         0.13  0.66    0.36  0.12
#     Proanthocyanins:              0.41  3.58    1.59  0.57
#     Colour Intensity:              1.3  13.0     5.1   2.3
#     Hue:                          0.48  1.71    0.96  0.23
#     OD280/OD315 of diluted wines: 1.27  4.00    2.61  0.71
#     Proline:                       278  1680     746   315
#     ============================= ==== ===== ======= =====
#
#     :Missing Attribute Values: None
#     :Class Distribution: class_0 (59), class_1 (71), class_2 (48)
#     :Creator: R.A. Fisher
#     :Donor: Michael Marshall (MARSHALL%PLU@io.arc.nasa.gov)
#     :Date: July, 1988
#
# This is a copy of UCI ML Wine recognition datasets.
# https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data
#
# The data is the results of a chemical analysis of wines grown in the same
# region in Italy by three different cultivators. There are thirteen different
# measurements taken for different constituents found in the three types of
# wine.
#
# Original Owners:
#
# Forina, M. et al, PARVUS -
# An Extendible Package for Data Exploration, Classification and Correlation.
# Institute of Pharmaceutical and Food Analysis and Technologies,
# Via Brigata Salerno, 16147 Genoa, Italy.
#
# Citation:
#
# Lichman, M. (2013). UCI Machine Learning Repository
# [https://archive.ics.uci.edu/ml]. Irvine, CA: University of California,
# School of Information and Computer Science.
#
# .. topic:: References
#
#   (1) S. Aeberhard, D. Coomans and O. de Vel,
#   Comparison of Classifiers in High Dimensional Settings,
#   Tech. Rep. no. 92-02, (1992), Dept. of Computer Science and Dept. of
#   Mathematics and Statistics, James Cook University of North Queensland.
#   (Also submitted to Technometrics).
#
#   The data was used with many others for comparing various
#   classifiers. The classes are separable, though only RDA
#   has achieved 100% correct classification.
#   (RDA : 100%, QDA 99.4%, LDA 98.9%, 1NN 96.1% (z-transformed data))
#   (All results using the leave-one-out technique)
#
#   (2) S. Aeberhard, D. Coomans and O. de Vel,
#   "THE CLASSIFICATION PERFORMANCE OF RDA"
#   Tech. Rep. no. 92-01, (1992), Dept. of Computer Science and Dept. of
#   Mathematics and Statistics, James Cook University of North Queensland.
#   (Also submitted to Journal of Chemometrics).

# %% [markdown]
# まず、演習書の事例にある「スラック変数の重みC」と「多項式カーネルの次数degree」の組み合わせでGridSearchを行います。
#
# パラメータとして多項式カーネルを与えて、サポートベクトルマシン[SVC](http://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html)のインスタンスsvcを作成します。

# %%
svc = SVC(kernel='poly', gamma='scale')
svc
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='poly',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %% [markdown]
# 演習書の事例の通り、「スラック変数の重みC」と「多項式カーネルの次数degree」の組み合わせで、リストを値とするディクショナリの配列param\_gridを作成します。

# %%
param_grid = [
  {'C': [1, 10, 100, 1000], 'degree': [1,2,3]}
 ]

# %% [markdown]
# 識別器のインスタンスを第1引数、グリッドを第2引数として、[GridSearch](http://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html)のインスタンスを作成し、fitメソッドを実行します。パラメータcvの値がNone（デフォルト）のとき、性能は3-fold CVで評価されます。

# %%
clf = GridSearchCV(svc, param_grid, cv=5, iid=False, return_train_score=True)
clf.fit(X, y)
# Out:
# GridSearchCV(cv=5, error_score='raise-deprecating',
#              estimator=SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#                            decision_function_shape='ovr', degree=3,
#                            gamma='scale', kernel='poly', max_iter=-1,
#                            probability=False, random_state=None, shrinking=True,
#                            tol=0.001, verbose=False),
#              iid=False, n_jobs=None,
#              param_grid=[{'C': [1, 10, 100, 1000], 'degree': [1, 2, 3]}],
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#              scoring=None, verbose=0)

# %% [markdown]
# 結果はcv\_results\_属性の値として、ディクショナリで得られます。

# %%
clf.cv_results_
# Out:
# {'mean_fit_time': array([0.00150008, 0.00078959, 0.00081563, 0.00074806, 0.00091186,
#         0.00084624, 0.00084677, 0.00110865, 0.0014349 , 0.0023509 ,
#         0.00786262, 0.0104496 ]),
#  'mean_score_time': array([0.00056229, 0.00031643, 0.00030661, 0.00034232, 0.00038342,
#         0.00031471, 0.00030842, 0.00031476, 0.0003305 , 0.00030823,
#         0.00036335, 0.00040646]),
#  'mean_test_score': array([0.66392283, 0.65296187, 0.66377268, 0.69838595, 0.67535998,
#         0.66423171, 0.7436513 , 0.72045802, 0.70343806, 0.84958589,
#         0.81684458, 0.78827239]),
#  'mean_train_score': array([0.68695736, 0.6939795 , 0.6897146 , 0.70660713, 0.7010223 ,
#         0.69114303, 0.73462992, 0.74875383, 0.73483595, 0.86955125,
#         0.85825367, 0.84144994]),
#  'param_C': masked_array(data=[1, 1, 1, 10, 10, 10, 100, 100, 100, 1000, 1000, 1000],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_degree': masked_array(data=[1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'C': 1, 'degree': 1},
#   {'C': 1, 'degree': 2},
#   {'C': 1, 'degree': 3},
#   {'C': 10, 'degree': 1},
#   {'C': 10, 'degree': 2},
#   {'C': 10, 'degree': 3},
#   {'C': 100, 'degree': 1},
#   {'C': 100, 'degree': 2},
#   {'C': 100, 'degree': 3},
#   {'C': 1000, 'degree': 1},
#   {'C': 1000, 'degree': 2},
#   {'C': 1000, 'degree': 3}],
#  'rank_test_score': array([10, 12, 11,  7,  8,  9,  4,  5,  6,  1,  2,  3], dtype=int32),
#  'split0_test_score': array([0.62162162, 0.59459459, 0.64864865, 0.62162162, 0.64864865,
#         0.59459459, 0.64864865, 0.64864865, 0.59459459, 0.78378378,
#         0.64864865, 0.67567568]),
#  'split0_train_score': array([0.73049645, 0.71631206, 0.70212766, 0.73049645, 0.73758865,
#         0.71631206, 0.75886525, 0.77304965, 0.78723404, 0.91489362,
#         0.89361702, 0.88652482]),
#  'split1_test_score': array([0.63888889, 0.63888889, 0.63888889, 0.63888889, 0.61111111,
#         0.61111111, 0.69444444, 0.66666667, 0.69444444, 0.75      ,
#         0.75      , 0.72222222]),
#  'split1_train_score': array([0.68309859, 0.71126761, 0.6971831 , 0.72535211, 0.71126761,
#         0.70422535, 0.73943662, 0.78169014, 0.75352113, 0.8943662 ,
#         0.86619718, 0.83098592]),
#  'split2_test_score': array([0.66666667, 0.63888889, 0.63888889, 0.69444444, 0.63888889,
#         0.69444444, 0.72222222, 0.75      , 0.75      , 0.91666667,
#         0.91666667, 0.86111111]),
#  'split2_train_score': array([0.69014085, 0.70422535, 0.70422535, 0.71830986, 0.70422535,
#         0.69014085, 0.73239437, 0.74647887, 0.73943662, 0.85915493,
#         0.85211268, 0.85211268]),
#  'split3_test_score': array([0.65714286, 0.65714286, 0.65714286, 0.74285714, 0.74285714,
#         0.68571429, 0.8       , 0.74285714, 0.74285714, 0.88571429,
#         0.85714286, 0.8       ]),
#  'split3_train_score': array([0.67132867, 0.68531469, 0.68531469, 0.67832168, 0.69230769,
#         0.68531469, 0.71328671, 0.72727273, 0.73426573, 0.82517483,
#         0.82517483, 0.81818182]),
#  'split4_test_score': array([0.73529412, 0.73529412, 0.73529412, 0.79411765, 0.73529412,
#         0.73529412, 0.85294118, 0.79411765, 0.73529412, 0.91176471,
#         0.91176471, 0.88235294]),
#  'split4_train_score': array([0.65972222, 0.65277778, 0.65972222, 0.68055556, 0.65972222,
#         0.65972222, 0.72916667, 0.71527778, 0.65972222, 0.85416667,
#         0.85416667, 0.81944444]),
#  'std_fit_time': array([4.15623078e-04, 3.26660949e-05, 3.51270759e-05, 3.03923751e-05,
#         1.14462135e-04, 5.31421268e-05, 3.83012157e-05, 9.03340278e-05,
#         1.93391337e-04, 3.71342324e-04, 3.91978543e-03, 3.39470467e-03]),
#  'std_score_time': array([1.64841206e-04, 8.83809665e-06, 4.86981256e-06, 4.53658372e-05,
#         4.46764610e-05, 9.94751344e-06, 2.68726402e-06, 4.34785549e-06,
#         1.93077248e-05, 1.15384740e-05, 3.27754013e-05, 2.46504058e-05]),
#  'std_test_score': array([0.03889331, 0.0460411 , 0.03640443, 0.06417233, 0.05351546,
#         0.05309482, 0.07351935, 0.05449823, 0.05773123, 0.06916439,
#         0.10330179, 0.07916415]),
#  'std_train_score': array([0.02411094, 0.02313119, 0.01636659, 0.022529  , 0.02543212,
#         0.01911475, 0.01483801, 0.02554348, 0.04185274, 0.03157768,
#         0.0221914 , 0.02561477])}

# %% [markdown]
# すべてのパラメータの組み合わせについて、スコアを表示します。

# %%
re = clf.cv_results_
for params, mean_score, std_score in zip(re['params'], re['mean_test_score'], re['std_test_score']):
    print("{:.3f} (+/- {:.3f}) for {}".format(mean_score, std_score, params))
# Out:
# 0.664 (+/- 0.039) for {'C': 1, 'degree': 1}
# 0.653 (+/- 0.046) for {'C': 1, 'degree': 2}
# 0.664 (+/- 0.036) for {'C': 1, 'degree': 3}
# 0.698 (+/- 0.064) for {'C': 10, 'degree': 1}
# 0.675 (+/- 0.054) for {'C': 10, 'degree': 2}
# 0.664 (+/- 0.053) for {'C': 10, 'degree': 3}
# 0.744 (+/- 0.074) for {'C': 100, 'degree': 1}
# 0.720 (+/- 0.054) for {'C': 100, 'degree': 2}
# 0.703 (+/- 0.058) for {'C': 100, 'degree': 3}
# 0.850 (+/- 0.069) for {'C': 1000, 'degree': 1}
# 0.817 (+/- 0.103) for {'C': 1000, 'degree': 2}
# 0.788 (+/- 0.079) for {'C': 1000, 'degree': 3}

# %% [markdown]
# 性能が最大となるパラメータとそのときのスコアを表示します。

# %%
clf.best_params_
# Out:
# {'C': 1000, 'degree': 1}

# %%
clf.best_score_
# Out:
# 0.8495858884094177

# %% [markdown]
# 次に、Cとgamma(RBF kernerl)の組み合わせでGridSearchを行います。
# まず、配列param_gridを作成します。

# %%
param_grid = [
  {'C':[1, 10, 100, 1000], 'gamma':[0.1, 0.01, 0.001, 0.0001]}
 ]

# %% [markdown]
# サポートベクトルマシンSVCのインスタンスsvcをRBFカーネルで作成し、GridSearchを行い、すべてのパラメータの組み合わせについて、スコアを表示します。

# %%
svc = SVC(kernel='rbf', gamma='scale')
svc
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
clf = GridSearchCV(svc, param_grid,cv=5, iid=False, return_train_score=True)
clf.fit(X, y)
# Out:
# GridSearchCV(cv=5, error_score='raise-deprecating',
#              estimator=SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#                            decision_function_shape='ovr', degree=3,
#                            gamma='scale', kernel='rbf', max_iter=-1,
#                            probability=False, random_state=None, shrinking=True,
#                            tol=0.001, verbose=False),
#              iid=False, n_jobs=None,
#              param_grid=[{'C': [1, 10, 100, 1000],
#                           'gamma': [0.1, 0.01, 0.001, 0.0001]}],
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#              scoring=None, verbose=0)

# %%
re = clf.cv_results_
for params, mean_score, std_score in zip(re['params'], re['mean_test_score'], re['std_test_score']):
    print("{:.3f} (+/- {:.3f}) for {}".format(mean_score, std_score, params))
# Out:
# 0.410 (+/- 0.018) for {'C': 1, 'gamma': 0.1}
# 0.642 (+/- 0.075) for {'C': 1, 'gamma': 0.01}
# 0.687 (+/- 0.056) for {'C': 1, 'gamma': 0.001}
# 0.714 (+/- 0.056) for {'C': 1, 'gamma': 0.0001}
# 0.417 (+/- 0.033) for {'C': 10, 'gamma': 0.1}
# 0.653 (+/- 0.075) for {'C': 10, 'gamma': 0.01}
# 0.748 (+/- 0.061) for {'C': 10, 'gamma': 0.001}
# 0.776 (+/- 0.054) for {'C': 10, 'gamma': 0.0001}
# 0.417 (+/- 0.033) for {'C': 100, 'gamma': 0.1}
# 0.653 (+/- 0.075) for {'C': 100, 'gamma': 0.01}
# 0.771 (+/- 0.070) for {'C': 100, 'gamma': 0.001}
# 0.855 (+/- 0.079) for {'C': 100, 'gamma': 0.0001}
# 0.417 (+/- 0.033) for {'C': 1000, 'gamma': 0.1}
# 0.653 (+/- 0.075) for {'C': 1000, 'gamma': 0.01}
# 0.771 (+/- 0.070) for {'C': 1000, 'gamma': 0.001}
# 0.872 (+/- 0.057) for {'C': 1000, 'gamma': 0.0001}

# %% [markdown]
# param\_gridに複数のグリッドを持たせることで、上記2回の実験を1回で行うことができます。その際、グリッドの情報にカーネルの種類を持たせることに注意してください。

# %%
param_grid = [
  {'C':[1, 10, 100, 1000], 'degree':[1, 2, 3], 'kernel':['poly']},
  {'C':[1, 10, 100, 1000], 'gamma':[0.1, 0.01, 0.001, 0.0001], 'kernel':['rbf']}
 ]

# %% [markdown]
# GridSearchを実行します。

# %%
clf = GridSearchCV(svc, param_grid, cv=5, iid=False)
clf.fit(X, y)
# Out:
# GridSearchCV(cv=5, error_score='raise-deprecating',
#              estimator=SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#                            decision_function_shape='ovr', degree=3,
#                            gamma='scale', kernel='rbf', max_iter=-1,
#                            probability=False, random_state=None, shrinking=True,
#                            tol=0.001, verbose=False),
#              iid=False, n_jobs=None,
#              param_grid=[{'C': [1, 10, 100, 1000], 'degree': [1, 2, 3],
#                           'kernel': ['poly']},
#                          {'C': [1, 10, 100, 1000],
#                           'gamma': [0.1, 0.01, 0.001, 0.0001],
#                           'kernel': ['rbf']}],
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %% [markdown]
# すべてのパラメータの組み合わせについて、スコアを表示します。

# %%
re = clf.cv_results_
for params, mean_score, std_score in zip(re['params'], re['mean_test_score'], re['std_test_score']):
    print("{:.3f} (+/- {:.3f}) for {}".format(mean_score, std_score, params))
# Out:
# 0.664 (+/- 0.039) for {'C': 1, 'degree': 1, 'kernel': 'poly'}
# 0.653 (+/- 0.046) for {'C': 1, 'degree': 2, 'kernel': 'poly'}
# 0.664 (+/- 0.036) for {'C': 1, 'degree': 3, 'kernel': 'poly'}
# 0.698 (+/- 0.064) for {'C': 10, 'degree': 1, 'kernel': 'poly'}
# 0.675 (+/- 0.054) for {'C': 10, 'degree': 2, 'kernel': 'poly'}
# 0.664 (+/- 0.053) for {'C': 10, 'degree': 3, 'kernel': 'poly'}
# 0.744 (+/- 0.074) for {'C': 100, 'degree': 1, 'kernel': 'poly'}
# 0.720 (+/- 0.054) for {'C': 100, 'degree': 2, 'kernel': 'poly'}
# 0.703 (+/- 0.058) for {'C': 100, 'degree': 3, 'kernel': 'poly'}
# 0.850 (+/- 0.069) for {'C': 1000, 'degree': 1, 'kernel': 'poly'}
# 0.817 (+/- 0.103) for {'C': 1000, 'degree': 2, 'kernel': 'poly'}
# 0.788 (+/- 0.079) for {'C': 1000, 'degree': 3, 'kernel': 'poly'}
# 0.410 (+/- 0.018) for {'C': 1, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.642 (+/- 0.075) for {'C': 1, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.687 (+/- 0.056) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.714 (+/- 0.056) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.417 (+/- 0.033) for {'C': 10, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.653 (+/- 0.075) for {'C': 10, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.748 (+/- 0.061) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.776 (+/- 0.054) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.417 (+/- 0.033) for {'C': 100, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.653 (+/- 0.075) for {'C': 100, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.771 (+/- 0.070) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.855 (+/- 0.079) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.417 (+/- 0.033) for {'C': 1000, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.653 (+/- 0.075) for {'C': 1000, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.771 (+/- 0.070) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.872 (+/- 0.057) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}

# %% [markdown]
# 性能が最大となるパラメータとそのときのスコアを表示します。

# %%
clf.best_params_
# Out:
# {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}

# %%
clf.best_score_
# Out:
# 0.871685214626391
